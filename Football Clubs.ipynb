# %%
import pandas as pd
import numpy as np
players={'defender':['Ramos','Varane'], 'attacker':['Hazard','Benzema'],}
Players=pd.DataFrame.from_dict(players)
print(Players)
# Out:
#   defender attacker
# 0    Ramos   Hazard
# 1   Varane  Benzema

# %%
df1=pd.read_csv('E:\Pyhton codes\season-1819.csv')

# %% [markdown]
# # Real Madrid DataFrame

# %%
df2=pd.read_csv('E:\Pyhton codes\data\data.csv')
def clean_team_dataframe(df2,str=None):
    df2=df2.where(df2['Club']==str).dropna(how='all')
    df2.set_index('Name',inplace=True)
    df2.drop(['Unnamed: 0','ID','Photo','Flag','Club Logo'],axis=1,inplace=True)
    return df2

# %%
Real_Madrid=pd.read_csv('E:\Pyhton codes\data\data.csv')
clean_team_dataframe(Real_Madrid,str='Real Madrid')
# Out:
#                   Age         Nationality  Overall  Potential         Club  \
# Name
# L. Modrić        32.0             Croatia     91.0       91.0  Real Madrid
# Sergio Ramos     32.0               Spain     91.0       91.0  Real Madrid
# T. Kroos         28.0             Germany     90.0       90.0  Real Madrid
# T. Courtois      26.0             Belgium     89.0       90.0  Real Madrid
# Casemiro         26.0              Brazil     88.0       90.0  Real Madrid
# Isco             26.0               Spain     88.0       91.0  Real Madrid
# Marcelo          30.0              Brazil     88.0       88.0  Real Madrid
# G. Bale          28.0               Wales     88.0       88.0  Real Madrid
# K. Navas         31.0          Costa Rica     87.0       87.0  Real Madrid
# R. Varane        25.0              France     86.0       91.0  Real Madrid
# Marco Asensio    22.0               Spain     85.0       92.0  Real Madrid
# ...

# %%
def get_mean_age(Real_Madrid,str='Real Madrid'):
    
    df=clean_team_dataframe(Real_Madrid,str)
    mean_age=df['Age'].mean()
    return mean_age

get_mean_age(Real_Madrid,str='Real Madrid')
# Out:
# 24.03030303030303

# %%
Barcelona=pd.read_csv('E:\Pyhton codes\data\data.csv')
clean_team_dataframe(Barcelona,str='FC Barcelona')
# Out:
#                   Age  Nationality  Overall  Potential          Club    Value  \
# Name
# L. Messi         31.0    Argentina     94.0       94.0  FC Barcelona  €110.5M
# L. Suárez        31.0      Uruguay     91.0       91.0  FC Barcelona     €80M
# M. ter Stegen    26.0      Germany     89.0       92.0  FC Barcelona     €58M
# Sergio Busquets  29.0        Spain     89.0       89.0  FC Barcelona   €51.5M
# Coutinho         26.0       Brazil     88.0       89.0  FC Barcelona   €69.5M
# S. Umtiti        24.0       France     87.0       92.0  FC Barcelona     €57M
# Jordi Alba       29.0        Spain     87.0       87.0  FC Barcelona     €38M
# I. Rakitić       30.0      Croatia     87.0       87.0  FC Barcelona   €46.5M
# Piqué            31.0        Spain     87.0       87.0  FC Barcelona     €34M
# A. Vidal         31.0        Chile     85.0       85.0  FC Barcelona     €26M
# O. Dembélé       21.0       France     83.0       92.0  FC Barcelona     €40M
# ...

# %%
get_mean_age(Barcelona,str='FC Barcelona')
# Out:
# 23.848484848484848

# %%
def get_mean_overall(Real_Madrid,str='Real Madrid'):
    
    df=clean_team_dataframe(Real_Madrid,str)
    mean_overall=df['Overall'].mean()
    return mean_overall

get_mean_overall(Real_Madrid,str='Real Madrid')
# Out:
# 78.24242424242425

# %%
get_mean_overall(Barcelona,str='FC Barcelona')
# Out:
# 78.03030303030303

# %%
# %matplotlib notebook

# %%
print(Barcelona['Age'])
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
# 5        27
# 6        32
# 7        31
# 8        32
# 9        25
# 10       29
# 11       28
# 12       32
# 13       32
# 14       27
# 15       24
# 16       24
# 17       27
# 18       26
# 19       26
# 20       29
# 21       31
# 22       32
# 23       30
# 24       33
# 25       19
# 26       26
# 27       26
# 28       26
# 29       27
#          ..
# 18177    18
# 18178    18
# 18179    17
# 18180    22
# 18181    17
# 18182    18
# 18183    44
# 18184    18
# 18185    19
# 18186    20
# 18187    19
# 18188    17
# 18189    18
# 18190    18
# 18191    18
# 18192    18
# 18193    18
# 18194    18
# 18195    18
# 18196    19
# 18197    18
# 18198    18
# 18199    18
# 18200    18
# 18201    18
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt

# %%
Real_Madrid=pd.read_csv('E:\Pyhton codes\data\data.csv')
Real_Madrid=clean_team_dataframe(Real_Madrid,str='Real Madrid')
rm_age=np.array(Real_Madrid['Age'])
rm_overall=np.array(Real_Madrid['Overall'])
plt.figure()
plt.scatter(rm_age,rm_overall)
plt.xlabel('Player Age')
plt.ylabel('Player Ability')
plt.title('Real Madrid: Age vs Ability')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5,1,'Real Madrid: Age vs Ability')

# %%
Barcelona=pd.read_csv('E:\Pyhton codes\data\data.csv')
Barcelona=clean_team_dataframe(Barcelona,str='FC Barcelona')
rm_age=np.array(Barcelona['Age'])
rm_overall=np.array(Barcelona['Overall'])
plt.figure()
plt.scatter(rm_age,rm_overall)
plt.xlabel('Player Age')
plt.ylabel('Player Ability')
plt.title('Barcelona: Age vs Ability')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Barcelona: Age vs Ability')

# %%
Real_Madrid=pd.read_csv('E:\Pyhton codes\data\data.csv')
Real_Madrid=clean_team_dataframe(Real_Madrid,str='Real Madrid')
Real_Madrid.plot('Age','Overall',kind='hist',bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Barcelona=pd.read_csv('E:\Pyhton codes\data\data.csv')
Barcelona=clean_team_dataframe(Barcelona,str='FC Barcelona')
Barcelona.plot('Age','Overall',kind='hist',bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">
